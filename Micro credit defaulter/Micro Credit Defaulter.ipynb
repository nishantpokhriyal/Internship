# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
mcd=pd.read_csv(r'C:\Internship\Micro credit defaulter\Micro Credit Project\Data_file.csv')

# %%
mcd
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
mcd.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
mcd.drop('Unnamed: 0', axis=1, inplace=True)

# %%
mcd
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111670  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228330  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
mcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# **No null values are present**

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
mcd.shape
# Out:
# (209593, 36)

# %%
mcd.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755200  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean     2692.581910    3483.406534         3755.84780        3712.202921
# std      4308.586781    5770.461279        53905.89223       53374.833430
# min    -23737.140000  -24720.580000          -29.00000         -29.000000
# ...

# %%
mcd.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
mcd.pcircle.unique()
# Out:
# array(['UPW'], dtype=object)

# %%
# pcircle only has one value so we are dropping it
mcd.drop('pcircle',axis=1,inplace=True)

# %%
mcd.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
# plotting heatmap to see the correlation
plt.figure(figsize=(20,16),dpi=100)
sns.heatmap(mcd.corr(),annot=True,linewidth=0.5,linecolor='White',annot_kws={'fontsize':6})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='cnt_loans30',data=mcd, palette='rocket_r')
sns.set_context('notebook')
plt.title("No. of loans taken by the user in the last 30 days", size =15)
# Out:
# Text(0.5, 1.0, 'No. of loans taken by the user in the last 30 days')

# %%
plt.figure(figsize=(12,4))
g=sns.countplot(x='amnt_loans30',data=mcd, palette='vlag')
sns.set_context('notebook')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title("Total Amount of loans taken by the user in the last 30 days", size =15)
# Out:
# Text(0.5, 1.0, 'Total Amount of loans taken by the user in the last 30 days')

# %%
sns.distplot( mcd["fr_ma_rech90"] , color="red")
sns.set_context('notebook')
plt.title("Frequency of main account recharged in last 90 days", size =16)
# Out:
# Text(0.5, 1.0, 'Frequency of main account recharged in last 90 days')

# %%
sns.distplot( mcd["fr_da_rech90"] , color="red")
sns.set_context('notebook')
plt.title("Frequency of data account recharged in last 90 days", size =16)
# Out:
# Text(0.5, 1.0, 'Frequency of data account recharged in last 90 days')

# %% [markdown]
# ## Model Creation for Label

# %%
mcd.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  amnt_loans30  \
# 0                2.0                0.0              1539  ...            12
# 1               20.0                0.0              5787  ...            12
# 2                3.0                0.0              1539  ...             6
# 3               41.0                0.0               947  ...            12
# 4                4.0                0.0              2309  ...            42
#
# ...

# %%
mcd.drop(columns=['msisdn','pdate'],axis=1,inplace=True)
mcd.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# 2                3.0                0.0              1539              1  ...
# 3               41.0                0.0               947              0  ...
# 4                4.0                0.0              2309              7  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# ...

# %%
x=mcd.drop(columns=['label'])
y=mcd[['label']]

print(x.shape)
print(y.shape)
# Out:
# (209593, 32)
# (209593, 1)

# %% [markdown]
# **We have created two variables containing Input data (x) and Output data (y).**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=50)

# %% [markdown]
# **We've splitted our dataset into training and testing, where we have used our 80% of data for training and 20% of data for testing**

# %% [markdown]
# ### Scaling x_train and x_test using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# **Making a function to calculate and print following features for the model : Accuracy Score, Confusion Matrix, Classification Report.**

# %%
def classifier_func(y_test,pred):
    ac=accuracy_score(y_test,pred)
    cm=confusion_matrix(y_test,pred)
    cr=classification_report(y_test,pred)
    
    print('Accuracy Score :',ac,'\n')
    print('Confusion Matrix :',cm,'\n')
    print('Classification Report :',cm,'\n')

# %% [markdown]
# **Making a Cross Validation function**

# %%
from sklearn.model_selection import cross_val_score
def cross_val_accuracy(model,x_train=x_train,y_train=y_train):
    accuracies=cross_val_score(estimator=model,X = x_train, y = y_train ,cv=10)
    print('Cross_val_Accuracy: {:.2f} %'.format(accuracies.mean()*100),'\n')
    print('Cross_val_Standard Deviation: {:.2f} %'.format(accuracies.std()*100),'\n')

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# **Creating Logistic Regression Model, it'll fit the Logistic Regression model on x_train and y_train and predict the x_test and store it in pred. We will print predicted Label and actual Label and outputs of the above functions**

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)

print('\033[1m' + 'LOGISTIC REGRESSION MODEL SUMMERY\n' + '\033[0m')
classifier_func(y_test,pred)
cross_val_accuracy(lr)

print('Predicted Label',pred)
print('\nActual Label\n',y_test)
# Out:
# LOGISTIC REGRESSION MODEL SUMMERY
#
# Accuracy Score : 0.8767384718146902
#
# Confusion Matrix : [[  111  5091]
#  [   76 36641]]
#
# Classification Report : [[  111  5091]
#  [   76 36641]]
#
# Cross_val_Accuracy: 87.62 %
#
# Cross_val_Standard Deviation: 0.04 %
#
# Predicted Label [1 1 1 ... 1 1 1]
#
# Actual Label
#          label
# 31638       1
# 196153      1
# 155522      0
# 107354      1
# 118699      1
# ...       ...
# 198410      1
# 165713      1
# 81510       1
# 13224       1
# 129496      1
#
# [41919 rows x 1 columns]

# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# **Creating Decision Tree Classifier Model, it'll fit the Decision Tree Classifier model on x_train and y_train and predict the x_test and store it in pred_dtc. We will print predicted Label and actual Label and outputs of the above functions**

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred_dtc=dtc.predict(x_test)

print('\033[1m' + 'DECISION TREE CLASSIFIER MODEL SUMMERY\n' + '\033[0m')
classifier_func(y_test,pred_dtc)
cross_val_accuracy(dtc)

print('Predicted Label',pred_dtc)
print('\nActual Label\n',y_test)
# Out:
# DECISION TREE CLASSIFIER MODEL SUMMERY
#
# Accuracy Score : 0.8672201149836589
#
# Confusion Matrix : [[ 2609  2593]
#  [ 2973 33744]]
#
# Classification Report : [[ 2609  2593]
#  [ 2973 33744]]
#
# Cross_val_Accuracy: 86.49 %
#
# Cross_val_Standard Deviation: 0.16 %
#
# Predicted Label [1 1 1 ... 1 1 1]
#
# Actual Label
#          label
# 31638       1
# 196153      1
# 155522      0
# 107354      1
# 118699      1
# ...       ...
# 198410      1
# 165713      1
# 81510       1
# 13224       1
# 129496      1
#
# [41919 rows x 1 columns]

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# **Creating Random Forest Classifier Model, it'll fit the Random Forest Classifier model on x_train and y_train and predict the x_test and store it in pred_rc. We will print predicted Label and actual Label and outputs of the above functions**

# %%
rc=RandomForestClassifier(n_estimators=100,random_state=42)
rc.fit(x_train,y_train)
pred_rc=rc.predict(x_test)

print('\033[1m' + 'RANDOM FOREST CLASSIFIER MODEL SUMMERY\n' + '\033[0m')
classifier_func(y_test,pred_rc)
cross_val_accuracy(rc)

print('Predicted Label',pred_rc)
print('\nActual Label\n',y_test)
# Out:
# RANDOM FOREST CLASSIFIER MODEL SUMMERY
#
# Accuracy Score : 0.9144779217061476
#
# Confusion Matrix : [[ 2313  2889]
#  [  696 36021]]
#
# Classification Report : [[ 2313  2889]
#  [  696 36021]]
#
# Cross_val_Accuracy: 91.22 %
#
# Cross_val_Standard Deviation: 0.16 %
#
# Predicted Label [1 1 1 ... 1 1 1]
#
# Actual Label
#          label
# 31638       1
# 196153      1
# 155522      0
# 107354      1
# 118699      1
# ...       ...
# 198410      1
# 165713      1
# 81510       1
# 13224       1
# 129496      1
#
# [41919 rows x 1 columns]

# %% [markdown]
# ### Gradient Boosting Classifier

# %% [markdown]
# **Creating Gradient Boosting Classifier Model, it'll fit the Gradient Boosting Classifier model on x_train and y_train and predict the x_test and store it in pred_gc. We will print predicted Label and actual Label and outputs of the above functions**

# %%
gc=GradientBoostingClassifier()
gc.fit(x_train,y_train)
pred_gc=gc.predict(x_test)

print('\033[1m' + 'GRADIENT BOOSTING CLASSIFIER MODEL SUMMERY\n' + '\033[0m')
classifier_func(y_test,pred_gc)
cross_val_accuracy(gc)

print('Predicted Label',pred_gc)
print('\nActual Label\n',y_test)
# Out:
# GRADIENT BOOSTING CLASSIFIER MODEL SUMMERY
#
# Accuracy Score : 0.9094444046852262
#
# Confusion Matrix : [[ 1839  3363]
#  [  433 36284]]
#
# Classification Report : [[ 1839  3363]
#  [  433 36284]]
#
# Cross_val_Accuracy: 90.86 %
#
# Cross_val_Standard Deviation: 0.11 %
#
# Predicted Label [1 1 1 ... 1 1 1]
#
# Actual Label
#          label
# 31638       1
# 196153      1
# 155522      0
# 107354      1
# 118699      1
# ...       ...
# 198410      1
# 165713      1
# 81510       1
# 13224       1
# 129496      1
#
# [41919 rows x 1 columns]

# %% [markdown]
# ### The best performing model for "Label" is Random Forest Classifier

# %% [markdown]
# ### Model Saving

# %%
import pickle
filename='mcd_label_model.pkl'
pickle.dump(rc,open(filename,'wb'))

# %% [markdown]
# **Random Forest Classifier Model is saved with the name "mcd_label_model"**

# %% [markdown]
# ## Conclusion

# %%
print('Predicted Result','\n', pred_rc)
print('Actual Result','\n', y_test)
# Out:
# Predicted Result
#  [1 1 1 ... 1 1 1]
# Actual Result
#          label
# 31638       1
# 196153      1
# 155522      0
# 107354      1
# 118699      1
# ...       ...
# 198410      1
# 165713      1
# 81510       1
# 13224       1
# 129496      1
#
# [41919 rows x 1 columns]

# %% [markdown]
# **As we can see above the model is predicted quite well**

# %% [markdown]
# # THE END
