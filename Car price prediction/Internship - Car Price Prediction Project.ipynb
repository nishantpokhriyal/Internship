# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
# Connect to the driver
driver=webdriver.Chrome(r'C:\Internship\Chrome driver\chromedriver.exe')

# %% [markdown]
# ## CARS24

# %%
cars24='https://www.cars24.com/'

# %%
driver.get(cars24)

# %%
# click button
driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button').click()

# %%
# selecting location manually
driver.find_element_by_xpath('/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button').click()

# %%
# clicking on New Delhi
driver.find_element_by_xpath('/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[1]/a/span/img').click()

# %%
# Ctreating Empty lists
brand=[]
model=[]
variant=[]
year=[]
driven=[]
fuel=[]
owners=[]
location=[]
price=[]
emi=[]
down_payment=[]

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')

# %%
# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)

# %%
len(brand)
# Out:
# 665

# %%
brand
# Out:
# ['2019 KIA SELTOS',
#  '2019 Hyundai Verna',
#  '2020 KIA SELTOS',
#  '2020 Maruti Swift',
#  '2019 Maruti Swift',
#  '2019 Tata NEXON',
#  '2020 KIA SELTOS',
#  '2020 Maruti Swift',
#  '2014 Honda City',
#  '2021 Renault Kwid',
#  '2020 Hyundai NEW SANTRO',
#  '2021 Maruti Swift',
#  '2019 Maruti Swift',
#  '2018 Maruti Dzire',
#  '2019 KIA SELTOS',
#  '2014 Mercedes Benz C Class',
#  '2017 Honda WR-V',
#  '2019 KIA SELTOS',
#  '2021 Renault Kiger',
#  '2013 Jaguar XF',
#  '2019 KIA SELTOS',
#  '2019 Hyundai Verna',
#  '2020 KIA SELTOS',
#  '2020 Maruti Swift',
#  '2019 Maruti Swift',
#  '2019 Tata NEXON',
#  '2020 KIA SELTOS',
#  '2020 Maruti Swift',
#  '2014 Honda City',
#  '2021 Renault Kwid',
#  '2020 Hyundai NEW SANTRO',
#  '2021 Maruti Swift',
#  '2019 Maruti Swift',
#  '2018 Maruti Dzire',
#  '2019 KIA SELTOS',
#  '2014 Mercedes Benz C Class',
#  '2017 Honda WR-V',
#  '2019 KIA SELTOS',
#  '2021 Renault Kiger',
#  '2013 Jaguar XF',
#  '2021 Tata ALTROZ',
# ...

# %%
# Extracting tags for model names
model_tag=driver.find_elements_by_xpath('//p[@class="cvakB"]')

# %%
# Extracting text from tags
for i in model_tag:
    n=i.text
    model.append(n)

# %%
len(model)
# Out:
# 665

# %%
model
# Out:
# ['HTK 1.5 PETROL Manual',
#  '1.6 SX VTVT (O) Manual',
#  'GTX + AT PETROL Automatic',
#  'LXI Manual',
#  'LXI Manual',
#  'XM 1.2 Manual',
#  'HTX 1.5 PETROL MT Manual',
#  'LXI Manual',
#  'VX MT PETROL Manual',
#  '1.0 RXT Opt Manual',
#  '1.1 ERA EXICUTIVE Manual',
#  'LXI Manual',
#  'LXI Manual',
#  'VXI AMT Automatic',
#  'HTK PLUS 1.5 DIESEL Manual',
#  'C 200 AVANTGARDE Automatic',
#  '1.2 i-VTEC VX MT Manual',
#  'GTX + AT PETROL Automatic',
#  'RXZ 1.0 MT DUAL TONE',
#  '2.2 DIESEL Automatic',
#  'HTK 1.5 PETROL Manual',
#  '1.6 SX VTVT (O) Manual',
#  'GTX + AT PETROL Automatic',
#  'LXI Manual',
#  'LXI Manual',
#  'XM 1.2 Manual',
#  'HTX 1.5 PETROL MT Manual',
#  'LXI Manual',
#  'VX MT PETROL Manual',
#  '1.0 RXT Opt Manual',
#  '1.1 ERA EXICUTIVE Manual',
#  'LXI Manual',
#  'LXI Manual',
#  'VXI AMT Automatic',
#  'HTK PLUS 1.5 DIESEL Manual',
#  'C 200 AVANTGARDE Automatic',
#  '1.2 i-VTEC VX MT Manual',
#  'GTX + AT PETROL Automatic',
#  'RXZ 1.0 MT DUAL TONE',
# ...

# %%
# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')

# %%
# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

# %%
len(driven)
# Out:
# 665

# %%
driven
# Out:
# ['9,918 km',
#  '81,902 km',
#  '8,241 km',
#  '10,568 km',
#  '27,659 km',
#  '28,061 km',
#  '32,799 km',
#  '19,919 km',
#  '61,168 km',
#  '368 km',
#  '3,812 km',
#  '5,078 km',
#  '24,967 km',
#  '12,545 km',
#  '25,067 km',
#  '37,531 km',
#  '17,511 km',
#  '37,357 km',
#  '14,474 km',
#  '28,909 km',
#  '9,918 km',
#  '81,902 km',
#  '8,241 km',
#  '10,568 km',
#  '27,659 km',
#  '28,061 km',
#  '32,799 km',
#  '19,919 km',
#  '61,168 km',
#  '368 km',
#  '3,812 km',
#  '5,078 km',
#  '24,967 km',
#  '12,545 km',
#  '25,067 km',
#  '37,531 km',
#  '17,511 km',
#  '37,357 km',
#  '14,474 km',
#  '28,909 km',
#  '7,416 km',
#  '23,629 km',
#  '72,229 km',
#  '41,439 km',
#  '28,210 km',
#  '48,001 km',
#  '38,042 km',
#  '44,327 km',
#  '42,490 km',
#  '7,472 km',
#  '1,086 km',
#  '32,873 km',
#  '3,483 km',
#  '5,306 km',
#  '16,198 km',
#  '63,753 km',
#  '13,021 km',
#  '23,327 km',
#  '46,860 km',
#  '6,669 km',
#  '6,192 km',
#  '12,090 km',
#  '95,793 km',
# ...

# %%
# Extracting tags for fuel names
fuel_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')


# Extracting text from tags
for i in fuel_tag:
    n=i.text
    fuel.append(n)
    
print(len(fuel))
# Out:
# 665

# %%
fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
# Extracting tags for owners names
owners_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')


# Extracting text from tags
for i in owners_tag:
    n=i.text
    owners.append(n)
    
print(len(owners))
# Out:
# 665

# %%
# Extracting tags for emi names
emi_tag=driver.find_elements_by_xpath('//div[@class="_2HFRN"]/strong')


# Extracting text from tags
for i in emi_tag:
    n=i.text
    emi.append(n)
    
print(len(emi))
# Out:
# 665

# %%
# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')

# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))
# Out:
# 665

# %%
# Extracting tags for down_payment names
down_payment_tag=driver.find_elements_by_xpath('//div[@class="JvSRy"]/span')


# Extracting text from tags
for i in down_payment_tag:
    n=i.text
    down_payment.append(n)
    
print(len(down_payment))
# Out:
# 665

# %%
down_payment
# Out:
# ['Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
#  'Zero Down Payment',
# ...

# %%
# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//p[@class="_1V4-O"]')
location_tag=location_tag*665

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 665

# %%
location
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
# Selecting different location
driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p').click()

# %%
# Selecting Mumbai location
driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div/div[2]/ul/li[4]/a/span/img').click()

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')


# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)
    
print(len(brand))
# Out:
# 1110

# %%
# Extracting tags for model names
model_tag=driver.find_elements_by_xpath('//p[@class="cvakB"]')


# Extracting text from tags
for i in model_tag:
    n=i.text
    model.append(n)
    
print(len(model))
# Out:
# 1110

# %%
# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')


# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

# %%
len(driven)
# Out:
# 1110

# %%
# Extracting tags for fuel names
fuel_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')


# Extracting text from tags
for i in fuel_tag:
    n=i.text
    fuel.append(n)
    
print(len(fuel))


# Extracting tags for owners names
owners_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')


# Extracting text from tags
for i in owners_tag:
    n=i.text
    owners.append(n)
    
print(len(owners))

# Extracting tags for emi names
emi_tag=driver.find_elements_by_xpath('//div[@class="_2HFRN"]/strong')


# Extracting text from tags
for i in emi_tag:
    n=i.text
    emi.append(n)
    
print(len(emi))

# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')


# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))

# Extracting tags for down_payment names
down_payment_tag=driver.find_elements_by_xpath('//div[@class="JvSRy"]/span')


# Extracting text from tags
for i in down_payment_tag:
    n=i.text
    down_payment.append(n)
    
print(len(down_payment))

# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//p[@class="_1V4-O"]')
location_tag=location_tag*445

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 1110
# 1110
# 1110
# 1110
# 1110
# 1110

# %%
# Selecting different location
driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p').click()

# %%
# Selecting Bengaluru location
driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div/div[2]/ul/li[6]/a/span/img').click()

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')


# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)
    
print(len(brand))
# Out:
# 1715

# %%
# Extracting tags for model names
model_tag=driver.find_elements_by_xpath('//p[@class="cvakB"]')


# Extracting text from tags
for i in model_tag:
    n=i.text
    model.append(n)
    
print(len(model))

# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')


# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

print(len(driven))

# Extracting tags for fuel names
fuel_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')


# Extracting text from tags
for i in fuel_tag:
    n=i.text
    fuel.append(n)
    
print(len(fuel))


# Extracting tags for owners names
owners_tag=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')


# Extracting text from tags
for i in owners_tag:
    n=i.text
    owners.append(n)
    
print(len(owners))

# Extracting tags for emi names
emi_tag=driver.find_elements_by_xpath('//div[@class="_2HFRN"]/strong')


# Extracting text from tags
for i in emi_tag:
    n=i.text
    emi.append(n)
    
print(len(emi))

# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')


# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))

# Extracting tags for down_payment names
down_payment_tag=driver.find_elements_by_xpath('//div[@class="JvSRy"]/span')


# Extracting text from tags
for i in down_payment_tag:
    n=i.text
    down_payment.append(n)
    
print(len(down_payment))

# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//p[@class="_1V4-O"]')
location_tag=location_tag*605

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 1715
# 1715
# 1715
# 1715
# 1715
# 1715
# 1715
# 1715

# %%
olx='https://www.olx.in/cars_c84'

# %%
driver.get(olx)

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//div[@class="_4aNdc"]')


# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)
    
print(len(brand))
# Out:
# 2215

# %%
# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//div[@class="KFHpP"]')


# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

print(len(driven))


# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//span[@class="_3GOwr"]')


# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))


# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//div[@class="_1zvfB"]')
location_tag=location_tag[:500]

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 2215
# 2215
# 2215

# %%
cardekho='https://www.cardekho.com/used-cars+in+delhi-ncr'

# %%
driver.get(cardekho)

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')

# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)
    
print(len(brand))
# Out:
# 4295

# %%
brand=brand[:3215]

# %%
print(len(brand))
# Out:
# 3215

# %%
# Extracting tags for model names
model_tag=driver.find_elements_by_xpath('//div[@class="car_variant"]')
model_tag=model_tag[:1000]

# Extracting text from tags
for i in model_tag:
    n=i.text
    model.append(n)
    
print(len(model))

# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//div[@class="truncate dotlist-2"]/div[1]')
driven_tag=driven_tag[:1000]

# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

print(len(driven))

# Extracting tags for fuel names
fuel_tag=driver.find_elements_by_xpath('//div[@class="truncate dotlist-2"]/div[2]')
fuel_tag=fuel_tag[:1000]

# Extracting text from tags
for i in fuel_tag:
    n=i.text
    fuel.append(n)
    
print(len(fuel))


# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//div[@class=" price"]')
price_tag=price_tag[:1000]

# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))


# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//h2[@class="tooltip fullheading mainheadingH2"]')
location_tag=location_tag*1000

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 2715
# 3215
# 2715
# 3215
# 3215

# %%
# change location
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[1]/div[1]/div[2]/input').click()

# %%
# Choosing Location Mumbai
driver.find_element_by_xpath('/html/body/div[2]/div/div[3]/div[3]/div/div/div[3]/section/div/ul/li[3]/a/span[3]').click()

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
brand_tag=brand_tag[:1000]

# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)
    
print(len(brand))
# Out:
# 4215

# %%
# Extracting tags for model names
model_tag=driver.find_elements_by_xpath('//div[@class="car_variant"]')
model_tag=model_tag[:1000]

# Extracting text from tags
for i in model_tag:
    n=i.text
    model.append(n)
    
print(len(model))

# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//div[@class="truncate dotlist-2"]/div[1]')
driven_tag=driven_tag[:1000]

# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

print(len(driven))

# Extracting tags for fuel names
fuel_tag=driver.find_elements_by_xpath('//div[@class="truncate dotlist-2"]/div[2]')
fuel_tag=fuel_tag[:1000]

# Extracting text from tags
for i in fuel_tag:
    n=i.text
    fuel.append(n)
    
print(len(fuel))


# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//div[@class=" price"]')
price_tag=price_tag[:1000]

# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))


# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//h2[@class="tooltip fullheading mainheadingH2"]')
location_tag=location_tag*1000

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 3715
# 4215
# 3715
# 4215
# 4215

# %%
# change location
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[1]/div[1]/div[2]/input').click()

# %%
# Choosing Location Bangalore
driver.find_element_by_xpath('/html/body/div[2]/div/div[3]/div[3]/div/div/div[3]/section/div/ul/li[2]/a/span[3]').click()

# %%
# Extracting tags for brand names
brand_tag=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
brand_tag=brand_tag[:1000]

# Extracting text from tags
for i in brand_tag:
    n=i.text
    brand.append(n)
    
print(len(brand))
# Out:
# 5215

# %%
# Extracting tags for model names
model_tag=driver.find_elements_by_xpath('//div[@class="car_variant"]')
model_tag=model_tag[:1000]

# Extracting text from tags
for i in model_tag:
    n=i.text
    model.append(n)
    
print(len(model))

# Extracting tags for driven kilometers
driven_tag=driver.find_elements_by_xpath('//div[@class="truncate dotlist-2"]/div[1]')
driven_tag=driven_tag[:1000]

# Extracting text from tags
for i in driven_tag:
    n=i.text
    driven.append(n)

print(len(driven))

# Extracting tags for fuel names
fuel_tag=driver.find_elements_by_xpath('//div[@class="truncate dotlist-2"]/div[2]')
fuel_tag=fuel_tag[:1000]

# Extracting text from tags
for i in fuel_tag:
    n=i.text
    fuel.append(n)
    
print(len(fuel))


# Extracting tags for price names
price_tag=driver.find_elements_by_xpath('//div[@class=" price"]')
price_tag=price_tag[:1000]

# Extracting text from tags
for i in price_tag:
    n=i.text
    price.append(n)
    
print(len(price))


# Extracting tags for location names
location_tag=driver.find_elements_by_xpath('//h2[@class="tooltip fullheading mainheadingH2"]')
location_tag=location_tag*1000

# Extracting text from tags
for i in location_tag:
    n=i.text
    location.append(n)
    
print(len(location))
# Out:
# 4715
# 5215
# 4715
# 5215
# 5215

# %%
brand=brand[:4715]
model=model[:4715]
fuel=fuel[:4715]

# %%
driven=driven[:4715]

# %%
owners=owners[:4715]

# %%
location=location[:4715]

# %%
emi=emi[:4715]
down_payment=down_payment[:4715]
price=price[:4715]

# %%
# Creating Dataframe
used_cars=pd.DataFrame({})

used_cars['Brand']=brand
used_cars['Model']=model
used_cars['Variant']='-'
used_cars['Manufacturing Year']='-'
used_cars['Driven Kilometers']=driven
used_cars['Fuel']=fuel
used_cars['Location']=location
used_cars['Price']=price

# %%
used_cars
# Out:
#                      Brand                      Model Variant  \
# 0          2019 KIA SELTOS      HTK 1.5 PETROL Manual       -
# 1       2019 Hyundai Verna     1.6 SX VTVT (O) Manual       -
# 2          2020 KIA SELTOS  GTX + AT PETROL Automatic       -
# 3        2020 Maruti Swift                 LXI Manual       -
# 4        2019 Maruti Swift                 LXI Manual       -
# ...                    ...                        ...     ...
# 4710     2018 Maruti Swift                  Sportz AT       -
# 4711   2016 Renault Duster        SLX 2.6 Turbo 8 Str       -
# 4712    2017 Hyundai Verna           1.6 VTVT SX Plus       -
# 4713     2007 Maruti Swift                ZXI MT BSIV       -
# 4714  2020 Mahindra XUV500                      Alpha       -
#
#      Manufacturing Year Driven Kilometers    Fuel                Location  \
# 0                     -          9,918 km  Petrol               New Delhi
# ...

# %%
used_cars.columns
# Out:
# Index(['Brand', 'Model', 'Variant', 'Manufacturing Year', 'Driven Kilometers',
#        'Fuel', 'Location', 'Price'],
#       dtype='object')

# %%
uc=used_cars

# %%
uc
# Out:
#                      Brand                      Model Variant  \
# 0          2019 KIA SELTOS      HTK 1.5 PETROL Manual       -
# 1       2019 Hyundai Verna     1.6 SX VTVT (O) Manual       -
# 2          2020 KIA SELTOS  GTX + AT PETROL Automatic       -
# 3        2020 Maruti Swift                 LXI Manual       -
# 4        2019 Maruti Swift                 LXI Manual       -
# ...                    ...                        ...     ...
# 4710     2018 Maruti Swift                  Sportz AT       -
# 4711   2016 Renault Duster        SLX 2.6 Turbo 8 Str       -
# 4712    2017 Hyundai Verna           1.6 VTVT SX Plus       -
# 4713     2007 Maruti Swift                ZXI MT BSIV       -
# 4714  2020 Mahindra XUV500                      Alpha       -
#
#      Manufacturing Year Driven Kilometers    Fuel                Location  \
# 0                     -          9,918 km  Petrol               New Delhi
# ...
